# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd.read_csv('fhv_tripdata_2019-01.csv', nrows=100)

# %%
df
# Out:
#    dispatching_base_num      pickup_datetime     dropOff_datetime  \
# 0                B00001  2019-01-01 00:30:00  2019-01-01 02:51:55
# 1                B00001  2019-01-01 00:45:00  2019-01-01 00:54:49
# 2                B00001  2019-01-01 00:15:00  2019-01-01 00:54:52
# 3                B00008  2019-01-01 00:19:00  2019-01-01 00:39:00
# 4                B00008  2019-01-01 00:27:00  2019-01-01 00:37:00
# ..                  ...                  ...                  ...
# 95               B00248  2019-01-01 00:11:09  2019-01-01 00:20:59
# 96               B00248  2019-01-01 00:52:34  2019-01-01 01:01:06
# 97               B00248  2019-01-01 00:17:44  2019-01-01 00:24:03
# 98               B00248  2019-01-01 00:00:10  2019-01-01 00:33:26
# 99               B00248  2019-01-01 00:06:00  2019-01-01 00:36:23
#
#     PUlocationID  DOlocationID  SR_Flag Affiliated_base_number
# 0            NaN           NaN      NaN                 B00001
# ...

# %%
pd.io.sql.get_schema(df, name='fhv_tripdata')
# Out:
# 'CREATE TABLE "fhv_tripdata" (\n"dispatching_base_num" TEXT,\n  "pickup_datetime" TEXT,\n  "dropOff_datetime" TEXT,\n  "PUlocationID" REAL,\n  "DOlocationID" REAL,\n  "SR_Flag" REAL,\n  "Affiliated_base_number" TEXT\n)'

# %%
print(pd.io.sql.get_schema(df, name='fhv_tripdata'))
# Out:
# CREATE TABLE "fhv_tripdata" (
# "dispatching_base_num" TEXT,
#   "pickup_datetime" TEXT,
#   "dropOff_datetime" TEXT,
#   "PUlocationID" REAL,
#   "DOlocationID" REAL,
#   "SR_Flag" REAL,
#   "Affiliated_base_number" TEXT
# )

# %%
pd.to_datetime(df.pickup_datetime)
# Out:
# 0    2019-01-01 00:30:00
# 1    2019-01-01 00:45:00
# 2    2019-01-01 00:15:00
# 3    2019-01-01 00:19:00
# 4    2019-01-01 00:27:00
#              ...
# 95   2019-01-01 00:11:09
# 96   2019-01-01 00:52:34
# 97   2019-01-01 00:17:44
# 98   2019-01-01 00:00:10
# 99   2019-01-01 00:06:00
# Name: pickup_datetime, Length: 100, dtype: datetime64[ns]

# %%
pd.to_datetime(df.dropOff_datetime)
# Out:
# 0    2019-01-01 02:51:55
# 1    2019-01-01 00:54:49
# 2    2019-01-01 00:54:52
# 3    2019-01-01 00:39:00
# 4    2019-01-01 00:37:00
#              ...
# 95   2019-01-01 00:20:59
# 96   2019-01-01 01:01:06
# 97   2019-01-01 00:24:03
# 98   2019-01-01 00:33:26
# 99   2019-01-01 00:36:23
# Name: dropOff_datetime, Length: 100, dtype: datetime64[ns]

# %%
df.pickup_datetime = pd.to_datetime(df.pickup_datetime)

# %%
df
# Out:
#    dispatching_base_num     pickup_datetime     dropOff_datetime  \
# 0                B00001 2019-01-01 00:30:00  2019-01-01 02:51:55
# 1                B00001 2019-01-01 00:45:00  2019-01-01 00:54:49
# 2                B00001 2019-01-01 00:15:00  2019-01-01 00:54:52
# 3                B00008 2019-01-01 00:19:00  2019-01-01 00:39:00
# 4                B00008 2019-01-01 00:27:00  2019-01-01 00:37:00
# ..                  ...                 ...                  ...
# 95               B00248 2019-01-01 00:11:09  2019-01-01 00:20:59
# 96               B00248 2019-01-01 00:52:34  2019-01-01 01:01:06
# 97               B00248 2019-01-01 00:17:44  2019-01-01 00:24:03
# 98               B00248 2019-01-01 00:00:10  2019-01-01 00:33:26
# 99               B00248 2019-01-01 00:06:00  2019-01-01 00:36:23
#
#     PUlocationID  DOlocationID  SR_Flag Affiliated_base_number
# 0            NaN           NaN      NaN                 B00001
# ...

# %%
df.dropOff_datetime = pd.to_datetime(df.dropOff_datetime)

# %%
df
# Out:
#    dispatching_base_num     pickup_datetime    dropOff_datetime  PUlocationID  \
# 0                B00001 2019-01-01 00:30:00 2019-01-01 02:51:55           NaN
# 1                B00001 2019-01-01 00:45:00 2019-01-01 00:54:49           NaN
# 2                B00001 2019-01-01 00:15:00 2019-01-01 00:54:52           NaN
# 3                B00008 2019-01-01 00:19:00 2019-01-01 00:39:00           NaN
# 4                B00008 2019-01-01 00:27:00 2019-01-01 00:37:00           NaN
# ..                  ...                 ...                 ...           ...
# 95               B00248 2019-01-01 00:11:09 2019-01-01 00:20:59           NaN
# 96               B00248 2019-01-01 00:52:34 2019-01-01 01:01:06           NaN
# 97               B00248 2019-01-01 00:17:44 2019-01-01 00:24:03           NaN
# 98               B00248 2019-01-01 00:00:10 2019-01-01 00:33:26           NaN
# 99               B00248 2019-01-01 00:06:00 2019-01-01 00:36:23           NaN
#
# ...

# %%
print(pd.io.sql.get_schema(df, name='fhv_tripdata'))
# Out:
# CREATE TABLE "fhv_tripdata" (
# "dispatching_base_num" TEXT,
#   "pickup_datetime" TIMESTAMP,
#   "dropOff_datetime" TIMESTAMP,
#   "PUlocationID" REAL,
#   "DOlocationID" REAL,
#   "SR_Flag" REAL,
#   "Affiliated_base_number" TEXT
# )

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
pip install psycopg2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='taxi_data_otro', con=engine))
# Out:
# CREATE TABLE taxi_data_otro (
# 	vendor_id BIGINT,
# 	pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	dropoff_datetime TEXT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	rate_code BIGINT,
# 	store_and_fwd_flag TEXT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	imp_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	pickup_location_id BIGINT,
# 	dropoff_location_id BIGINT
# )

# %%
df_iter = pd.read_csv('archivo.csv', iterator=True, chunksize=1000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
df
# Out:
#      vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0            1  2018-03-27T12:47:16  2018-03-27T13:39:54                1
# 1            1  2018-06-10T19:02:02  2018-06-10T19:31:53                1
# 2            2  2018-10-23T20:35:45  2018-10-23T21:05:05                1
# 3            1  2018-09-11T20:13:27  2018-09-11T20:36:56                1
# 4            2  2018-06-20T22:20:22  2018-06-20T22:45:24                2
# ..         ...                  ...                  ...              ...
# 995          1  2018-07-06T09:00:21  2018-07-06T09:09:12                1
# 996          2  2018-06-19T06:28:54  2018-06-19T06:36:44                1
# 997          1  2018-10-11T21:42:07  2018-10-11T21:52:18                1
# 998          1  2018-12-03T09:43:26  2018-12-03T09:53:31                1
# 999          2  2018-03-01T00:45:20  2018-03-01T00:55:26                2
#
#      trip_distance  rate_code store_and_fwd_flag  payment_type  fare_amount  \
# ...

# %%
len(df)
# Out:
# 1000

# %%
df.pickup_datetime = pd.to_datetime(df.pickup_datetime)
df.dropoff_datetime = pd.to_datetime(df.dropoff_datetime)

# %%
df.head()
# Out:
#    vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# 0          1 2018-03-27 12:47:16 2018-03-27 13:39:54                1
# 1          1 2018-06-10 19:02:02 2018-06-10 19:31:53                1
# 2          2 2018-10-23 20:35:45 2018-10-23 21:05:05                1
# 3          1 2018-09-11 20:13:27 2018-09-11 20:36:56                1
# 4          2 2018-06-20 22:20:22 2018-06-20 22:45:24                2
#
#    trip_distance  rate_code store_and_fwd_flag  payment_type  fare_amount  \
# 0           2.70          1                  N             1         29.0
# 1          15.10          1                  N             1         42.0
# 2           7.92          1                  N             1         26.0
# 3           6.50          1                  N             1         22.5
# 4           6.44          1                  N             1         24.5
#
#    extra  mta_tax  tip_amount  tolls_amount  imp_surcharge  total_amount  \
# ...

# %%
df.head(n=0)
# Out:
# Empty DataFrame
# Columns: [vendor_id, pickup_datetime, dropoff_datetime, passenger_count, trip_distance, rate_code, store_and_fwd_flag, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, imp_surcharge, total_amount, pickup_location_id, dropoff_location_id]
# Index: []

# %%
df.head(n=1)
# Out:
#    vendor_id     pickup_datetime    dropoff_datetime  passenger_count  \
# 0          1 2018-03-27 12:47:16 2018-03-27 13:39:54                1
#
#    trip_distance  rate_code store_and_fwd_flag  payment_type  fare_amount  \
# 0            2.7          1                  N             1         29.0
#
#    extra  mta_tax  tip_amount  tolls_amount  imp_surcharge  total_amount  \
# 0    0.0      0.5        5.95           0.0            0.3         35.75
#
#    pickup_location_id  dropoff_location_id
# 0                  68                  162

# %%
len(df)
# Out:
# 1000

# %%
df.head(n=0).to_sql(name='taxi_data_otro', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='taxi_data_otro', con=engine, if_exists='append')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 169 ms
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    
    df = next(df_iter)

    df.pickup_datetime = pd.to_datetime(df.pickup_datetime)
    df.dropoff_datetime = pd.to_datetime(df.dropoff_datetime)

    df.to_sql(name='taxi_data_otro', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk....., took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk....., took 15.726 second
# inserted another chunk....., took 15.291 second
# C:\Users\aYo\AppData\Local\Temp\ipykernel_10052\1107623301.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk....., took 15.056 second
# inserted another chunk....., took 11.277 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[76], line 4
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next(df_iter)
#       6     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#       7     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
#    1842     try:
# ...

# %%
while True:
    t_start = time()
    
    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk....., took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk....., took 14.932 second
# inserted another chunk....., took 15.230 second
# inserted another chunk....., took 14.611 second
# inserted another chunk....., took 10.598 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[89], line 4
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next(df_iter)
#       6     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#       7     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
#    1842     try:
# -> 1843         return self.get_chunk()
#    1844     except StopIteration:
#    1845         self.close()
#
# ...

# %%
while True:
    t_start = time()
    
    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk....., took %.3f second' % (t_end - t_start))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[90], line 4
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next(df_iter)
#       6     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#       7     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
#    1842     try:
# -> 1843         return self.get_chunk()
#    1844     except StopIteration:
#    1845         self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1985, in TextFileReader.get_chunk(self, size)
#    1983         raise StopIteration
#    1984     size = min(size, self.nrows - self._currow)
# -> 1985 return self.read(nrows=size)
#
# ...

# %%
df_iter = pd.read_csv('green_tripdata_2019-10.csv', iterator=True, chunksize=10000, low_memory=False)

# %%
while True:
    t_start = time()
    
    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk....., took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk....., took 1.273 second
# inserted another chunk....., took 1.460 second
# inserted another chunk....., took 1.357 second
# inserted another chunk....., took 1.585 second
# inserted another chunk....., took 1.606 second
# inserted another chunk....., took 1.556 second
# inserted another chunk....., took 1.627 second
# inserted another chunk....., took 1.371 second
# inserted another chunk....., took 1.600 second
# inserted another chunk....., took 1.593 second
# inserted another chunk....., took 1.679 second
# inserted another chunk....., took 1.539 second
# inserted another chunk....., took 1.632 second
# inserted another chunk....., took 1.304 second
# inserted another chunk....., took 1.429 second
# inserted another chunk....., took 1.500 second
# inserted another chunk....., took 1.563 second
# inserted another chunk....., took 1.610 second
# inserted another chunk....., took 1.585 second
# inserted another chunk....., took 1.642 second
# ...

# %%
df_iter = pd.read_csv('green_tripdata_2019-10.csv', iterator=True, chunksize=10000, low_memory=False)

# %%
df_iter = pd.read_csv('green_tripdata_2019-10.csv', iterator=True, chunksize=1000, low_memory=False)

# %%
while True:
    t_start = time()
    
    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk....., took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk....., took 0.150 second
# inserted another chunk....., took 0.181 second
# inserted another chunk....., took 0.173 second
# inserted another chunk....., took 0.118 second
# inserted another chunk....., took 0.190 second
# inserted another chunk....., took 0.158 second
# inserted another chunk....., took 0.149 second
# inserted another chunk....., took 0.118 second
# inserted another chunk....., took 0.134 second
# inserted another chunk....., took 0.117 second
# inserted another chunk....., took 0.185 second
# inserted another chunk....., took 0.189 second
# inserted another chunk....., took 0.170 second
# inserted another chunk....., took 0.144 second
# inserted another chunk....., took 0.127 second
# inserted another chunk....., took 0.154 second
# inserted another chunk....., took 0.131 second
# inserted another chunk....., took 0.227 second
# inserted another chunk....., took 0.181 second
# inserted another chunk....., took 0.166 second
# ...

# %%
df_iter = pd.read_csv('green_tripdata_2019-10.csv', iterator=True, chunksize=1000, low_memory=False)

# %%
while True:
    t_start = time()
    
    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk....., took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk....., took 0.379 second
# inserted another chunk....., took 0.215 second
# inserted another chunk....., took 0.194 second
# inserted another chunk....., took 0.157 second
# inserted another chunk....., took 0.115 second
# inserted another chunk....., took 0.156 second
# inserted another chunk....., took 0.174 second
# inserted another chunk....., took 0.165 second
# inserted another chunk....., took 0.137 second
# inserted another chunk....., took 0.190 second
# inserted another chunk....., took 0.205 second
# inserted another chunk....., took 0.138 second
# inserted another chunk....., took 0.130 second
# inserted another chunk....., took 0.190 second
# inserted another chunk....., took 0.175 second
# inserted another chunk....., took 0.192 second
# inserted another chunk....., took 0.177 second
# inserted another chunk....., took 0.181 second
# inserted another chunk....., took 0.122 second
# inserted another chunk....., took 0.177 second
# ...
